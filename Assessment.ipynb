# %% [markdown]
# ## Assessment assignments answered
#
# This will be the notebook where everything relating to the assessment exercices happens, coupled with a small explanation of how and why for each.
#
# ### 1. Acquiring the data, and making it useful
#
# we want a ranking list of countried by number of airports, then the top and bottom 10, along with their respective number of airports, as well as the width and length of the longest runway for each country, and which airport that runway belongs to.
#
# #### Importing the csv files, and answering parts 1 and 2

# %%
import pandas as pd

airports  = pd.read_csv("airports.csv")
countries = pd.read_csv("countries.csv")
runways   = pd.read_csv("runways.csv")

# We can take the list of airports and count them per country, then sorting the result
num_airports = airports.groupby("iso_country").size().sort_values(ascending=False).reset_index(name="counts")

# To easily read the country names, we pull the names from the second file, and make the translation
country_ids = countries.loc[:, "code" : "name"].set_index("code")
num_airports = num_airports.set_index("iso_country").merge(country_ids, left_on="iso_country", right_on="code").set_index("name")
num_airports.rename(columns={"counts" : "airports"}, inplace=True)

assert countries.shape[0] >= num_airports.shape[0]

print("The 10 countries with the most airports are:")
print(num_airports.head(10))

# We're showing the 15 countries with the least airports, to show that there are 14 with exactly 1, so those 14 all share the last spot
print("The 10 countries with the least airports are:")
print(num_airports.tail(15))
# Out:
# The 10 countries with the most airports are:
#                 airports
# name
# United States      25170
# Brazil              5546
# Canada              2829
# Australia           2038
# Mexico              1779
# Japan               1761
# South Korea         1378
# Russia              1306
# United Kingdom      1289
# Germany              967
# The 10 countries with the least airports are:
#                                 airports
# name
# Saint Pierre and Miquelon              2
# Gambia                                 1
# Mayotte                                1
# Gibraltar                              1
# Vatican City                           1
# British Indian Ocean Territory         1
# Jersey                                 1
# Niue                                   1
# Nauru                                  1
# Saint Barthélemy                       1
# Christmas Island                       1
# Curaçao                                1
# Sint Maarten                           1
# Norfolk Island                         1
# Cocos (Keeling) Islands                1

# %% [markdown]
# #### Answering the runway question
#
# The list of longest runway width and length per country is a bit more tricky, but still very doable; every runway belongs to an airport, situated in a country, so we need to add the country each runway is in to the dataframe, so we can group by country.

# %%
# First we link all airport ids to the country the airport is in, then do the same with all runways
airport_countries = airports.loc[:, : "iso_country"].merge(country_ids, left_on="iso_country", right_on="code").set_index("id")
airport_countries = airport_countries.loc[:,"name_x" :].rename(columns={"name_x" : "airport", "name_y" : "country"})
airport_countries.drop(columns=["latitude_deg", "longitude_deg", "elevation_ft", "continent", "iso_country"], inplace=True)
longest_runways = airport_countries.merge(runways, left_on="id", right_on="airport_ref")
del airport_countries

# having linked the runways to their respective airports and countries, it's a matter of grouping the countries by longest runway
longest_runways = longest_runways[longest_runways.groupby(["country"])["length_ft"].transform(max) == longest_runways["length_ft"]]
longest_runways = longest_runways.set_index("country").loc[:, : "width_ft"].drop(columns=["id", "airport_ref", "airport_ident"])
longest_runways = longest_runways.reset_index().drop_duplicates(["country"]).sort_values("country").set_index("country")

assert countries.shape[0] >= longest_runways.shape[0]

for row in longest_runways.itertuples(True):
    print(f"The longest runway in {row[0]} is {row.length_ft}ft long, {row.width_ft} wide, and belongs to the airport named {row.airport}")
# Out:
# The longest runway in Afghanistan is 11820.0ft long, 151.0 wide, and belongs to the airport named Bagram Airfield
# The longest runway in Albania is 9318.0ft long, 220.0 wide, and belongs to the airport named Kuçovë Air Base
# The longest runway in Algeria is 12737.0ft long, 246.0 wide, and belongs to the airport named Tinfouchy Airport
# The longest runway in American Samoa is 10000.0ft long, 150.0 wide, and belongs to the airport named Pago Pago International Airport
# The longest runway in Angola is 12190.0ft long, 148.0 wide, and belongs to the airport named Quatro de Fevereiro Airport
# The longest runway in Anguilla is 5462.0ft long, 98.0 wide, and belongs to the airport named Clayton J Lloyd International Airport
# The longest runway in Antarctica is 12000.0ft long, 200.0 wide, and belongs to the airport named South Pole Station Airport
# The longest runway in Antigua and Barbuda is 9003.0ft long, 148.0 wide, and belongs to the airport named V.C. Bird International Airport
# The longest runway in Argentina is 11644.0ft long, 148.0 wide, and belongs to the airport named Piloto Civil N. Fernández Airport
# The longest runway in Armenia is 12629.0ft long, 184.0 wide, and belongs to the airport named Zvartnots International Airport
# The longest runway in Aruba is 9000.0ft long, 148.0 wide, and belongs to the airport named Queen Beatrix International Airport
# The longest runway in Australia is 12999.0ft long, 148.0 wide, and belongs to the airport named Sydney Kingsford Smith International Airport
# The longest runway in Austria is 11811.0ft long, 148.0 wide, and belongs to the airport named Vienna International Airport
# The longest runway in Azerbaijan is 13123.0ft long, 197.0 wide, and belongs to the airport named Heydar Aliyev International Airport
# The longest runway in Bahamas is 11353.0ft long, 150.0 wide, and belongs to the airport named Lynden Pindling International Airport
# The longest runway in Bahrain is 12979.0ft long, 197.0 wide, and belongs to the airport named Bahrain International Airport
# The longest runway in Bangladesh is 11500.0ft long, 150.0 wide, and belongs to the airport named Hazrat Shahjalal International Airport
# The longest runway in Barbados is 11000.0ft long, 150.0 wide, and belongs to the airport named Grantley Adams International Airport
# The longest runway in Belarus is 12139.0ft long, 197.0 wide, and belongs to the airport named Minsk National Airport
# The longest runway in Belgium is 12106.0ft long, 148.0 wide, and belongs to the airport named Liège Airport
# The longest runway in Belize is 9022.0ft long, 197.0 wide, and belongs to the airport named Riversdale International Airport
# The longest runway in Benin is 7874.0ft long, 148.0 wide, and belongs to the airport named Cadjehoun Airport
# The longest runway in Bermuda is 9705.0ft long, 150.0 wide, and belongs to the airport named L.F. Wade International International Airport
# The longest runway in Bhutan is 7431.0ft long, 98.0 wide, and belongs to the airport named Paro Airport
# The longest runway in Bolivia is 13123.0ft long, 151.0 wide, and belongs to the airport named El Alto International Airport
# The longest runway in Bosnia and Herzegovina is 8666.0ft long, 150.0 wide, and belongs to the airport named Sarajevo International Airport
# The longest runway in Botswana is 13123.0ft long, 148.0 wide, and belongs to the airport named Sir Seretse Khama International Airport
# The longest runway in Brazil is 13123.0ft long, 148.0 wide, and belongs to the airport named Rio Galeão – Tom Jobim International Airport
# The longest runway in British Indian Ocean Territory is 12003.0ft long, 200.0 wide, and belongs to the airport named Diego Garcia Naval Support Facility
# The longest runway in British Virgin Islands is 4642.0ft long, 89.0 wide, and belongs to the airport named Terrance B. Lettsome International Airport
# The longest runway in Brunei is 12000.0ft long, 150.0 wide, and belongs to the airport named Brunei International Airport
# The longest runway in Bulgaria is 11811.0ft long, 147.0 wide, and belongs to the airport named Sofia Airport
# The longest runway in Burkina Faso is 10826.0ft long, 148.0 wide, and belongs to the airport named Bobo Dioulasso Airport
# The longest runway in Burma is 14003.0ft long, 200.0 wide, and belongs to the airport named Mandalay International Airport
# The longest runway in Burundi is 11811.0ft long, 148.0 wide, and belongs to the airport named Bujumbura Melchior Ndadaye International Airport
# The longest runway in Cambodia is 9843.0ft long, 144.0 wide, and belongs to the airport named Phnom Penh International Airport
# The longest runway in Cameroon is 11155.0ft long, 148.0 wide, and belongs to the airport named Yaoundé Nsimalen International Airport
# The longest runway in Canada is 120000.0ft long, 1000.0 wide, and belongs to the airport named Pontiac Airpark Water Aerodrome
# The longest runway in Cape Verde is 10735.0ft long, 148.0 wide, and belongs to the airport named Amílcar Cabral International Airport
# The longest runway in Caribbean Netherlands is 9449.0ft long, 148.0 wide, and belongs to the airport named Flamingo International Airport
# The longest runway in Cayman Islands is 7021.0ft long, 148.0 wide, and belongs to the airport named Owen Roberts International Airport
# The longest runway in Central African Republic is 8530.0ft long, 148.0 wide, and belongs to the airport named Bangui M'Poko International Airport
# The longest runway in Chad is 9186.0ft long, 98.0 wide, and belongs to the airport named Abeche Airport
# The longest runway in Chile is 12303.0ft long, 180.0 wide, and belongs to the airport named Comodoro Arturo Merino Benítez International Airport
# The longest runway in China is 18045.0ft long, 148.0 wide, and belongs to the airport named Qamdo Bangda Airport
# The longest runway in Christmas Island is 6900.0ft long, 148.0 wide, and belongs to the airport named Christmas Island Airport
# The longest runway in Cocos (Keeling) Islands is 7999.0ft long, 148.0 wide, and belongs to the airport named Cocos (Keeling) Islands Airport
# The longest runway in Colombia is 12467.0ft long, 148.0 wide, and belongs to the airport named El Dorado International Airport
# The longest runway in Comoros is 9514.0ft long, 148.0 wide, and belongs to the airport named Prince Said Ibrahim International Airport
# The longest runway in Congo (Brazzaville) is 10827.0ft long, 148.0 wide, and belongs to the airport named Maya-Maya Airport
# The longest runway in Congo (Kinshasa) is 15420.0ft long, 197.0 wide, and belongs to the airport named Ndjili International Airport
# The longest runway in Cook Islands is 7638.0ft long, 150.0 wide, and belongs to the airport named Rarotonga International Airport
# The longest runway in Costa Rica is 9882.0ft long, 151.0 wide, and belongs to the airport named Juan Santamaría International Airport
# The longest runway in Croatia is 10827.0ft long, 148.0 wide, and belongs to the airport named Dubrovnik Airport
# The longest runway in Cuba is 13130.0ft long, 148.0 wide, and belongs to the airport named Antonio Maceo International Airport
# The longest runway in Curaçao is 11188.0ft long, 197.0 wide, and belongs to the airport named Hato International Airport
# The longest runway in Cyprus is 9776.0ft long, 148.0 wide, and belongs to the airport named Larnaca International Airport
# The longest runway in Czech Republic is 12189.0ft long, 148.0 wide, and belongs to the airport named Václav Havel Airport Prague
# The longest runway in Côte d'Ivoire is 10827.0ft long, 148.0 wide, and belongs to the airport named Bouaké Airport
# The longest runway in Denmark is 11811.0ft long, 148.0 wide, and belongs to the airport named Copenhagen Kastrup Airport
# The longest runway in Djibouti is 10335.0ft long, 150.0 wide, and belongs to the airport named Djibouti-Ambouli Airport
# The longest runway in Dominica is 4777.0ft long, 148.0 wide, and belongs to the airport named Douglas-Charles Airport
# The longest runway in Dominican Republic is 11000.0ft long, 200.0 wide, and belongs to the airport named Las Américas International Airport
# The longest runway in Ecuador is 13445.0ft long, 148.0 wide, and belongs to the airport named Mariscal Sucre International Airport
# The longest runway in Egypt is 13124.0ft long, 197.0 wide, and belongs to the airport named Cairo International Airport
# The longest runway in El Salvador is 10500.0ft long, 148.0 wide, and belongs to the airport named Monseñor Óscar Arnulfo Romero International Airport
# The longest runway in Equatorial Guinea is 10860.0ft long, 200.0 wide, and belongs to the airport named Bata Airport
# The longest runway in Eritrea is 11531.0ft long, 148.0 wide, and belongs to the airport named Assab International Airport
# The longest runway in Estonia is 11417.0ft long, 148.0 wide, and belongs to the airport named Lennart Meri Tallinn Airport
# The longest runway in Eswatini is 11811.0ft long, 197.0 wide, and belongs to the airport named King Mswati III International Airport
# The longest runway in Ethiopia is 12467.0ft long, 148.0 wide, and belongs to the airport named Addis Ababa Bole International Airport
# The longest runway in Falkland Islands is 8497.0ft long, 150.0 wide, and belongs to the airport named Mount Pleasant Airport
# The longest runway in Faroe Islands is 5902.0ft long, 98.0 wide, and belongs to the airport named Vágar Airport
# The longest runway in Fiji is 10739.0ft long, 150.0 wide, and belongs to the airport named Nadi International Airport
# The longest runway in Finland is 11286.0ft long, 197.0 wide, and belongs to the airport named Helsinki Vantaa Airport
# The longest runway in France is 13829.0ft long, 148.0 wide, and belongs to the airport named Charles de Gaulle International Airport
# The longest runway in French Guiana is 10486.0ft long, 148.0 wide, and belongs to the airport named Cayenne – Félix Eboué Airport
# The longest runway in French Polynesia is 11360.0ft long, 148.0 wide, and belongs to the airport named Faa'a International Airport
# The longest runway in French Southern Territories is 4921.0ft long, nan wide, and belongs to the airport named Europa Island Airstrip
# The longest runway in Gabon is 10105.0ft long, 148.0 wide, and belongs to the airport named M'Vengue El Hadj Omar Bongo Ondimba International Airport
# The longest runway in Gambia is 11811.0ft long, 148.0 wide, and belongs to the airport named Banjul International Airport
# The longest runway in Georgia is 12012.0ft long, 172.0 wide, and belongs to the airport named Sukhumi Babushara /  Vladislav Ardzinba International Airport
# The longest runway in Germany is 13123.0ft long, 148.0 wide, and belongs to the airport named Berlin Brandenburg Airport
# The longest runway in Ghana is 11165.0ft long, 200.0 wide, and belongs to the airport named Kotoka International Airport
# The longest runway in Gibraltar is 6000.0ft long, 150.0 wide, and belongs to the airport named Gibraltar Airport
# The longest runway in Greece is 13123.0ft long, 148.0 wide, and belongs to the airport named Eleftherios Venizelos International Airport
# The longest runway in Greenland is 15000.0ft long, 200.0 wide, and belongs to the airport named Summit Ice Landingstrip
# The longest runway in Grenada is 9003.0ft long, 148.0 wide, and belongs to the airport named Point Salines International Airport
# The longest runway in Guadeloupe is 11499.0ft long, 148.0 wide, and belongs to the airport named Pointe-à-Pitre Le Raizet
# The longest runway in Guam is 12015.0ft long, 150.0 wide, and belongs to the airport named Antonio B. Won Pat International Airport
# The longest runway in Guatemala is 9842.0ft long, 148.0 wide, and belongs to the airport named Mundo Maya International Airport
# The longest runway in Guernsey is 5194.0ft long, 148.0 wide, and belongs to the airport named Guernsey Airport
# The longest runway in Guinea is 10826.0ft long, 148.0 wide, and belongs to the airport named Conakry International Airport
# The longest runway in Guinea-Bissau is 10499.0ft long, 148.0 wide, and belongs to the airport named Osvaldo Vieira International Airport
# The longest runway in Guyana is 7448.0ft long, 148.0 wide, and belongs to the airport named Cheddi Jagan International Airport
# The longest runway in Haiti is 9974.0ft long, 141.0 wide, and belongs to the airport named Toussaint Louverture International Airport
# The longest runway in Honduras is 9875.0ft long, 147.0 wide, and belongs to the airport named Goloson International Airport
# The longest runway in Hong Kong is 12467.0ft long, 197.0 wide, and belongs to the airport named Hong Kong International Airport
# The longest runway in Hungary is 12162.0ft long, 149.0 wide, and belongs to the airport named Budapest Liszt Ferenc International Airport
# The longest runway in Iceland is 10056.0ft long, 197.0 wide, and belongs to the airport named Keflavik International Airport
# The longest runway in India is 14534.0ft long, 197.0 wide, and belongs to the airport named Indira Gandhi International Airport
# The longest runway in Indonesia is 13270.0ft long, 148.0 wide, and belongs to the airport named Hang Nadim International Airport
# The longest runway in Iran is 14664.0ft long, 148.0 wide, and belongs to the airport named Bushehr Airport
# The longest runway in Iraq is 15748.0ft long, 246.0 wide, and belongs to the airport named Erbil International Airport
# The longest runway in Ireland is 10495.0ft long, 148.0 wide, and belongs to the airport named Shannon Airport
# The longest runway in Isle of Man is 5751.0ft long, 151.0 wide, and belongs to the airport named Isle of Man Airport
# The longest runway in Israel is 13327.0ft long, 148.0 wide, and belongs to the airport named Ben Gurion International Airport
# The longest runway in Italy is 12861.0ft long, 197.0 wide, and belongs to the airport named Malpensa International Airport
# The longest runway in Jamaica is 8900.0ft long, 150.0 wide, and belongs to the airport named Norman Manley International Airport
# The longest runway in Japan is 13124.0ft long, 200.0 wide, and belongs to the airport named JASDF Chitose Air Base
# The longest runway in Jersey is 5597.0ft long, 148.0 wide, and belongs to the airport named Jersey Airport
# The longest runway in Jordan is 12008.0ft long, 200.0 wide, and belongs to the airport named Queen Alia International Airport
# The longest runway in Kazakhstan is 14765.0ft long, 275.0 wide, and belongs to the airport named Yubileyniy Airfield
# The longest runway in Kenya is 13507.0ft long, 148.0 wide, and belongs to the airport named Jomo Kenyatta International Airport
# The longest runway in Kiribati is 6900.0ft long, 98.0 wide, and belongs to the airport named Cassidy International Airport
# The longest runway in Kosovo is 8165.0ft long, 148.0 wide, and belongs to the airport named Priština Adem Jashari International Airport
# The longest runway in Kuwait is 11483.0ft long, 148.0 wide, and belongs to the airport named Kuwait International Airport
# The longest runway in Kyrgyzstan is 13780.0ft long, 180.0 wide, and belongs to the airport named Manas International Airport
# The longest runway in Laos is 9843.0ft long, 148.0 wide, and belongs to the airport named Wattay International Airport
# The longest runway in Latvia is 10499.0ft long, 148.0 wide, and belongs to the airport named Riga International Airport
# The longest runway in Lebanon is 12467.0ft long, 148.0 wide, and belongs to the airport named Beirut Rafic Hariri International Airport
# The longest runway in Lesotho is 10498.0ft long, 148.0 wide, and belongs to the airport named Moshoeshoe I International Airport
# The longest runway in Liberia is 11000.0ft long, 150.0 wide, and belongs to the airport named Roberts International Airport
# The longest runway in Libya is 13729.0ft long, 197.0 wide, and belongs to the airport named Al Jufra Airport
# The longest runway in Lithuania is 11483.0ft long, 148.0 wide, and belongs to the airport named Šiauliai International Airport
# The longest runway in Luxembourg is 13123.0ft long, 197.0 wide, and belongs to the airport named Luxembourg-Findel International Airport
# The longest runway in Macau is 10544.0ft long, 148.0 wide, and belongs to the airport named Macau International Airport
# The longest runway in Madagascar is 10171.0ft long, 148.0 wide, and belongs to the airport named Ivato Airport
# The longest runway in Malawi is 11614.0ft long, 148.0 wide, and belongs to the airport named Lilongwe International Airport
# The longest runway in Malaysia is 13530.0ft long, 197.0 wide, and belongs to the airport named Kuala Lumpur International Airport
# The longest runway in Maldives is 12000.0ft long, 165.0 wide, and belongs to the airport named Gan International Airport
# The longest runway in Mali is 10498.0ft long, 148.0 wide, and belongs to the airport named Modibo Keita International Airport
# The longest runway in Malta is 11627.0ft long, 197.0 wide, and belongs to the airport named Malta International Airport
# The longest runway in Marshall Islands is 7897.0ft long, 150.0 wide, and belongs to the airport named Marshall Islands International Airport
# The longest runway in Martinique is 10826.0ft long, 147.0 wide, and belongs to the airport named Martinique Aimé Césaire International Airport
# The longest runway in Mauritania is 11155.0ft long, 197.0 wide, and belongs to the airport named Nouakchott–Oumtounsy International Airport
# The longest runway in Mauritius is 11056.0ft long, 148.0 wide, and belongs to the airport named Sir Seewoosagur Ramgoolam International Airport
# The longest runway in Mayotte is 6330.0ft long, 92.0 wide, and belongs to the airport named Dzaoudzi Pamandzi International Airport
# The longest runway in Mexico is 13780.0ft long, 148.0 wide, and belongs to the airport named Licenciado Adolfo Lopez Mateos International Airport
# The longest runway in Micronesia is 6006.0ft long, 150.0 wide, and belongs to the airport named Chuuk International Airport
# The longest runway in Moldova is 11779.0ft long, 145.0 wide, and belongs to the airport named Chişinău International Airport
# The longest runway in Mongolia is 10170.0ft long, 197.0 wide, and belongs to the airport named Buyant-Ukhaa International Airport
# The longest runway in Montenegro is 8208.0ft long, 148.0 wide, and belongs to the airport named Tivat Airport
# The longest runway in Montserrat is 1968.0ft long, nan wide, and belongs to the airport named John A. Osborne Airport
# The longest runway in Morocco is 12205.0ft long, 148.0 wide, and belongs to the airport named Mohammed V International Airport
# The longest runway in Mozambique is 12008.0ft long, 148.0 wide, and belongs to the airport named Maputo Airport
# The longest runway in Namibia is 15010.0ft long, 148.0 wide, and belongs to the airport named Hosea Kutako International Airport
# The longest runway in Nauru is 7054.0ft long, 148.0 wide, and belongs to the airport named Nauru International Airport
# The longest runway in Nepal is 10007.0ft long, 148.0 wide, and belongs to the airport named Tribhuvan International Airport
# The longest runway in Netherlands is 12467.0ft long, 198.0 wide, and belongs to the airport named Amsterdam Airport Schiphol
# The longest runway in New Caledonia is 10663.0ft long, 148.0 wide, and belongs to the airport named La Tontouta International Airport
# The longest runway in New Zealand is 11926.0ft long, 148.0 wide, and belongs to the airport named Auckland International Airport
# The longest runway in Nicaragua is 9862.0ft long, 148.0 wide, and belongs to the airport named Punta Huete (Panchito) Airport
# The longest runway in Niger is 9843.0ft long, 148.0 wide, and belongs to the airport named Diori Hamani International Airport
# The longest runway in Nigeria is 12794.0ft long, 197.0 wide, and belongs to the airport named Murtala Muhammed International Airport
# The longest runway in Niue is 7660.0ft long, 148.0 wide, and belongs to the airport named Niue International Airport
# The longest runway in Norfolk Island is 6398.0ft long, 150.0 wide, and belongs to the airport named Norfolk Island International Airport
# The longest runway in North Korea is 12475.0ft long, 197.0 wide, and belongs to the airport named Pyongyang Sunan International Airport
# The longest runway in North Macedonia is 9678.0ft long, 148.0 wide, and belongs to the airport named Skopje International Airport
# The longest runway in Northern Mariana Islands is 8700.0ft long, 200.0 wide, and belongs to the airport named Saipan International Airport
# The longest runway in Norway is 11811.0ft long, 148.0 wide, and belongs to the airport named Oslo Gardermoen Airport
# The longest runway in Oman is 13123.0ft long, 194.0 wide, and belongs to the airport named Duqm International Airport
# The longest runway in Pakistan is 12001.0ft long, 147.0 wide, and belongs to the airport named Islamabad International Airport
# The longest runway in Palau is 7200.0ft long, 150.0 wide, and belongs to the airport named Babelthuap Airport
# The longest runway in Palestinian Territory is 6447.0ft long, 148.0 wide, and belongs to the airport named Jerusalem International Airport
# The longest runway in Panama is 10006.0ft long, 148.0 wide, and belongs to the airport named Tocumen International Airport
# The longest runway in Papua New Guinea is 9022.0ft long, 148.0 wide, and belongs to the airport named Port Moresby Jacksons International Airport
# The longest runway in Paraguay is 11483.0ft long, 131.0 wide, and belongs to the airport named Dr. Luis Maria Argaña International Airport
# The longest runway in Perú is 13779.0ft long, 150.0 wide, and belongs to the airport named Inca Manco Capac International Airport
# The longest runway in Philippines is 12261.0ft long, 197.0 wide, and belongs to the airport named Ninoy Aquino International Airport
# The longest runway in Poland is 12106.0ft long, 196.0 wide, and belongs to the airport named Warsaw Chopin Airport
# The longest runway in Portugal is 12484.0ft long, 148.0 wide, and belongs to the airport named Humberto Delgado Airport (Lisbon Portela Airport)
# The longest runway in Puerto Rico is 11702.0ft long, 200.0 wide, and belongs to the airport named Rafael Hernandez Airport
# The longest runway in Qatar is 15912.0ft long, 197.0 wide, and belongs to the airport named Hamad International Airport
# The longest runway in Romania is 11484.0ft long, 148.0 wide, and belongs to the airport named Henri Coandă International Airport
# The longest runway in Russia is 16404.0ft long, 323.0 wide, and belongs to the airport named Ulyanovsk East Airport
# The longest runway in Rwanda is 11483.0ft long, 148.0 wide, and belongs to the airport named Kigali International Airport
# The longest runway in Réunion is 10499.0ft long, 148.0 wide, and belongs to the airport named Roland Garros Airport
# The longest runway in Saint Barthélemy is 2133.0ft long, 49.0 wide, and belongs to the airport named Gustaf III Airport / Saint Barthélemy Rémy de Haenen Airport
# The longest runway in Saint Helena is 10019.0ft long, 150.0 wide, and belongs to the airport named RAF Ascension Island
# The longest runway in Saint Kitts and Nevis is 7602.0ft long, 148.0 wide, and belongs to the airport named Robert L. Bradshaw International Airport
# The longest runway in Saint Lucia is 9003.0ft long, 148.0 wide, and belongs to the airport named Hewanorra International Airport
# The longest runway in Saint Martin is 3937.0ft long, 98.0 wide, and belongs to the airport named Grand Case-Espérance Airport
# The longest runway in Saint Pierre and Miquelon is 5900.0ft long, 150.0 wide, and belongs to the airport named St Pierre Airport
# The longest runway in Saint Vincent and the Grenadines is 9000.0ft long, 148.0 wide, and belongs to the airport named Argyle International Airport
# The longest runway in Samoa is 9843.0ft long, 148.0 wide, and belongs to the airport named Faleolo International Airport
# The longest runway in San Marino is 2133.0ft long, 98.0 wide, and belongs to the airport named Aviosuperficie Torraccia
# The longest runway in Saudi Arabia is 13796.0ft long, 197.0 wide, and belongs to the airport named King Khaled International Airport
# The longest runway in Senegal is 11483.0ft long, 197.0 wide, and belongs to the airport named Blaise Diagne International Airport
# The longest runway in Serbia is 11155.0ft long, 148.0 wide, and belongs to the airport named Belgrade Nikola Tesla Airport
# The longest runway in Seychelles is 9800.0ft long, 151.0 wide, and belongs to the airport named Seychelles International Airport
# The longest runway in Sierra Leone is 10498.0ft long, 150.0 wide, and belongs to the airport named Lungi International Airport
# The longest runway in Singapore is 13123.0ft long, 197.0 wide, and belongs to the airport named Singapore Changi Airport /  Changi Air Base (West)
# The longest runway in Sint Maarten is 7708.0ft long, 148.0 wide, and belongs to the airport named Princess Juliana International Airport
# The longest runway in Slovakia is 10466.0ft long, 148.0 wide, and belongs to the airport named M. R. Štefánik Airport
# The longest runway in Slovenia is 10827.0ft long, 148.0 wide, and belongs to the airport named Ljubljana Jože Pučnik Airport
# The longest runway in Solomon Islands is 7218.0ft long, 148.0 wide, and belongs to the airport named Honiara International Airport
# The longest runway in Somalia is 13582.0ft long, 164.0 wide, and belongs to the airport named Berbera Airport
# The longest runway in South Africa is 16076.0ft long, 197.0 wide, and belongs to the airport named Pierre Van Ryneveld Airport
# The longest runway in South Korea is 13000.0ft long, 197.0 wide, and belongs to the airport named Incheon International Airport
# The longest runway in South Sudan is 10171.0ft long, 148.0 wide, and belongs to the airport named Juba International Airport
# The longest runway in Spain is 13711.0ft long, 197.0 wide, and belongs to the airport named Adolfo Suárez Madrid–Barajas Airport
# The longest runway in Sri Lanka is 11483.0ft long, 197.0 wide, and belongs to the airport named Mattala Rajapaksa International Airport
# The longest runway in Sudan is 13186.0ft long, 197.0 wide, and belongs to the airport named Merowe New Airport
# The longest runway in Suriname is 11417.0ft long, 148.0 wide, and belongs to the airport named Johan Adolf Pengel International Airport
# The longest runway in Sweden is 10990.0ft long, 148.0 wide, and belongs to the airport named Luleå Airport
# The longest runway in Switzerland is 12795.0ft long, 164.0 wide, and belongs to the airport named Geneva Cointrin International Airport
# The longest runway in Syria is 11860.0ft long, 150.0 wide, and belongs to the airport named Qamishli Airport
# The longest runway in São Tomé and Principe is 7283.0ft long, 148.0 wide, and belongs to the airport named São Tomé International Airport
# The longest runway in Taiwan is 12008.0ft long, 197.0 wide, and belongs to the airport named Taiwan Taoyuan International Airport
# The longest runway in Tajikistan is 10450.0ft long, 164.0 wide, and belongs to the airport named Khudzhand Airport
# The longest runway in Tanzania is 11834.0ft long, 148.0 wide, and belongs to the airport named Kilimanjaro International Airport
# The longest runway in Thailand is 13123.0ft long, 197.0 wide, and belongs to the airport named Suvarnabhumi Airport
# The longest runway in Timor-Leste is 8233.0ft long, 182.0 wide, and belongs to the airport named Cakung Airport
# The longest runway in Togo is 9847.0ft long, 148.0 wide, and belongs to the airport named Lomé–Tokoin International Airport
# The longest runway in Tonga is 8795.0ft long, 147.0 wide, and belongs to the airport named Fua'amotu International Airport
# The longest runway in Trinidad and Tobago is 10500.0ft long, 150.0 wide, and belongs to the airport named Piarco International Airport
# The longest runway in Tunisia is 10826.0ft long, 196.0 wide, and belongs to the airport named Enfidha - Hammamet International Airport
# The longest runway in Turkey is 13451.0ft long, 196.0 wide, and belongs to the airport named İstanbul Airport
# The longest runway in Turkmenistan is 12467.0ft long, 151.0 wide, and belongs to the airport named Ashgabat International Airport
# The longest runway in Turks and Caicos Islands is 7598.0ft long, 148.0 wide, and belongs to the airport named Providenciales Airport
# The longest runway in Tuvalu is 5040.0ft long, nan wide, and belongs to the airport named Funafuti International Airport
# The longest runway in U.S. Virgin Islands is 10004.0ft long, 150.0 wide, and belongs to the airport named Henry E Rohlsen Airport
# The longest runway in Uganda is 12000.0ft long, 150.0 wide, and belongs to the airport named Entebbe International Airport
# The longest runway in Ukraine is 13123.0ft long, 197.0 wide, and belongs to the airport named Boryspil International Airport
# The longest runway in United Arab Emirates is 14764.0ft long, 197.0 wide, and belongs to the airport named Al Maktoum International Airport
# The longest runway in United Kingdom is 12799.0ft long, 164.0 wide, and belongs to the airport named London Heathrow Airport
# The longest runway in United States is 30000.0ft long, 5000.0 wide, and belongs to the airport named Gunflint Seaplane Base
# The longest runway in United States Minor Outlying Islands is 9843.0ft long, 150.0 wide, and belongs to the airport named Wake Island Airfield
# The longest runway in Uruguay is 10499.0ft long, 148.0 wide, and belongs to the airport named Carrasco International /General C L Berisso Airport
# The longest runway in Uzbekistan is 13123.0ft long, 197.0 wide, and belongs to the airport named Tashkent International Airport
# The longest runway in Vanuatu is 8530.0ft long, 148.0 wide, and belongs to the airport named Bauerfield International Airport
# The longest runway in Venezuela is 11483.0ft long, 148.0 wide, and belongs to the airport named Simón Bolívar International Airport
# The longest runway in Vietnam is 12468.0ft long, 148.0 wide, and belongs to the airport named Tan Son Nhat International Airport
# The longest runway in Wallis and Futuna is 6890.0ft long, 148.0 wide, and belongs to the airport named Hihifo Airport
# The longest runway in Western Sahara is 9850.0ft long, 100.0 wide, and belongs to the airport named Smara Airport
# The longest runway in Yemen is 11483.0ft long, nan wide, and belongs to the airport named Sadah Airport
# The longest runway in Zambia is 12998.0ft long, 150.0 wide, and belongs to the airport named Kenneth Kaunda International Airport
# The longest runway in Zimbabwe is 15502.0ft long, 151.0 wide, and belongs to the airport named Robert Gabriel Mugabe International Airport

# %% [markdown]
# ### 2. Uploading to cloud storage
#
# Now that we have these answers, we want to upload the dataframes that give us these answers to a cloud block-storage service. We're given the credentials, so we use those, and upload the dataframes after writing them to csv files first.

# %%
from azure.storage.blob import *

acc_name  = "sacodeassessment"
acc_SAS   = "se=2022-03-10T15%3A46Z&sp=rcwd&spr=https&sv=2018-11-09&sr=c&sig=Wf6AQ%2BoLm3mtRq%2BHTvvGt7BzBmUOqz/4QPzTUezcUZo%3D"
container = "results"
blob_path = "/ingest-airports-20220216-robert"

blob = BlobClient.from_blob_url(f"https://{acc_name}.blob.core.windows.net/" + container + blob_path, credential=acc_SAS)

if blob.exists():
    blob.delete_blob("include")
answers = num_airports.join(longest_runways).rename_axis("country")
blob.upload_blob(answers.to_csv())
# Out:
# {'etag': '"0x8D9F86F8B30634B"',
#  'last_modified': datetime.datetime(2022, 2, 25, 15, 0, 20, tzinfo=datetime.timezone.utc),
#  'content_md5': bytearray(b'\xe0\xaa\x8a$\xdcc\x1a\xf8\x9e\xc0EO\xa3\xbb4&'),
#  'client_request_id': 'a6cfd0c6-964b-11ec-b225-ec63d7c84d34',
#  'request_id': '274ddfab-f01e-000e-8058-2a1f7f000000',
#  'version': '2020-10-02',
#  'version_id': None,
#  'date': datetime.datetime(2022, 2, 25, 15, 0, 20, tzinfo=datetime.timezone.utc),
#  'request_server_encrypted': True,
#  'encryption_key_sha256': None,
#  'encryption_scope': None}

# %% [markdown]
# ### Navigating eCommerce RDBMS
#
# We aim to evaluate the total spending of all people who've bought jazz music against people who haven't. This is spending per person, so we need to accumulate the totals for every buyer, then seperate then into jazz and non-jazz, and average those values, comparing those final two values. All info we need for this is in an sql database, with the given credentials.

# %%
password = input("Please input the password:")

# %% [markdown]
# To keep the password private, I'm asking for the password as input when running the previous block of code, so we can use the connection without constantly asking for the password going forward.

# %%
from sqlalchemy import create_engine
import psycopg2 as psy

# Connecting to the PostgreSQL Server v13, by making the sqlalchemy engine
dialect  = "postgresql"
driver   = "psycopg2"
hostname = "code-assessment-001.westeurope.cloudapp.azure.com"
port     = 5432
database = "chinook"
username = "larry"
# engine = create_engine(f"{dialect}+{driver}://{username}:{password}@{hostname}:{port}/{database})")

connection = psy.connect(host=hostname, database=database, user=username, password=password, port=port)
cursor = connection.cursor()

cursor.execute("SELECT table_schema, table_name FROM information_schema.tables WHERE (table_schema = 'public')")
fetched_list = cursor.fetchall()
table_list = [pair[1] for pair in fetched_list]
print(table_list)
# Out:
# ['film', 'artist', 'album', 'employee', 'customer', 'invoice', 'invoice_line', 'track', 'playlist', 'playlist_track', 'genre', 'media_type', 'film_actor', 'film_category', 'actor', 'category']

# %% [markdown]
# Since using sqlalchemy has been tried and is it failed, we'll be manually importing the data into pandas dataframes, writing our own function, and using that repeatedly. We get the column names from

# %%
genre, track, line, invoice = "genre_id", "track_id", "invoice_line_id", "invoice_id"
customer, unit, quant, jazz = "customer_id", "unit_price", "quantity", "Jazz"

def get_column_names(table_name : str):
    cursor.execute(f"SELECT * FROM {table_name} LIMIT 0;")
    
    return [desc[0] for desc in cursor.description]


def import_from_sql(table_name : str, make_index : bool = True):
    cursor.execute(f"SELECT * FROM {table_name};")
    colnames = [desc[0] for desc in cursor.description]
    tuples = cursor.fetchall()
    dictry = {column : [] for column in colnames}

    for row in tuples:
        for i, column in enumerate(colnames):
            dictry[column].append(row[i])
    if make_index:
        return pd.DataFrame.from_dict(dictry).set_index(colnames[0])
    else:
        return pd.DataFrame.from_dict(dictry)

#Importing the dataframes as we go, only using the data we need, since we only care about Jazz, we're renaming all other genre names to Not Jazz
genre_df = import_from_sql("genre")
genre_df.loc[genre_df["name"] != jazz] = "Not Jazz"

# Converting the track ids to the genre names Jazz and Not Jazz
tracks_df = import_from_sql("track").drop(columns=[col for col in get_column_names("track") if col not in [genre, track]])
tracks_df = tracks_df.merge(genre_df, left_on=genre, right_index=True).rename(columns={"name" : "genre"}).drop(columns=[genre])
del genre_df

# Doing the same for all invoice lines and invoices, and for invoices with multiple lines; if it has one line with Jazz, it has Jazz,
inv_line_df = import_from_sql("invoice_line", False).set_index(invoice)
inv_line_df = inv_line_df.drop(columns=[col for col in get_column_names("invoice_line") if col not in [invoice, track]])
inv_line_df = inv_line_df.merge(tracks_df, left_on=track, right_index=True).drop(columns=[track]).reset_index()
inv_line_df = inv_line_df.sort_values("genre").drop_duplicates(invoice, keep="first").set_index(invoice).sort_index()
del tracks_df

# to link the invoices to customers, we need the invoice table as well, then the customer table
invoice_df = import_from_sql("invoice").drop(columns=[col for col in get_column_names("invoice") if col not in [invoice, customer]])
invoice_df = invoice_df.join(inv_line_df).reset_index().drop(columns=[invoice])
invoice_df = invoice_df.sort_values("genre").drop_duplicates(customer, keep="first").set_index(customer).sort_index()
customer_total_df = invoice_df
customer_genre_df = invoice_df
del inv_line_df

# This gives us a list of who has, and who hasn't bought Jazz music at some point
# Linking this back to invoices, we can sum the total spending of each customer, so we can check larry's hypothesis.
invoice_df = import_from_sql("invoice", False).drop(columns=[col for col in get_column_names("invoice") if col not in [invoice, customer]]).set_index(customer)
customer_total_df = customer_total_df.join(invoice_df)
inv_line_df = import_from_sql("invoice_line", False).set_index(invoice).drop(columns=[col for col in get_column_names("invoice_line") if col not in [invoice, unit, quant]])
customer_total_df = customer_total_df.merge(inv_line_df, left_on=invoice, right_index=True).drop(columns=[invoice])
customer_total_df[unit] = pd.to_numeric(customer_total_df[unit], downcast="float")

# We have all the information we need now, so we mold this a little bit to compare the two statistics:
# Average total spending of people who HAVE bought Jazz music vs people who's NEVEr bought Jazz music. 
customer_total_df[unit] = customer_total_df[unit]*customer_total_df[quant]
customer_total_df = customer_total_df.groupby(customer).sum().join(customer_genre_df)
customer_total_df = customer_total_df.set_index("genre").drop(columns=[quant]).rename(columns={unit : "total spending"})
customer_total_df = customer_total_df.groupby("genre").mean()
del invoice_df, inv_line_df, customer_genre_df
customer_total_df
# Out:
#           total spending
# genre
# Jazz           38.964375
# Not Jazz       40.064445

# %% [markdown]
# Clearly, this disproves Larry's hypothesis, as not only do people that buy Jazz music not spend a lot more than people who don't, they actually spend less, even if not by much.
#
# #### Part 2: the new killer-app
#
# Next we take a look at a new killer app Larry has thought up, where people can input a trackname, and they get a list of all albums that contain that track. So far, he's tried the following, and we aim to improve upon this:
# ```
# SELECT album.title
# FROM   track
# JOIN   album ON (track.album_id = album.album_id)
# WHERE  LOWER(track.name) = LOWER('Enter Sandman')
# ```

# %%
def get_albums(trackname : str):
    """trackname is the name of a track, and returns a list of album names that contain the given track"""
    sql_statement = f"""SELECT album.title
                        FROM track
                        INNER JOIN album ON (track.album_id = album.album_id)
                        WHERE LOWER(track.name) = LOWER('{trackname}')"""
    cursor.execute(sql_statement)
    albumlist = [name[0] for name in cursor.fetchall()]

    return albumlist

# This fixes Larry's function very simply by changing the 'JOIN' into an 'INNER JOIN', because it's only relevant to look at matching values in both tables

for album in get_albums("Enter Sandman"):
    print(album)
# Out:
# Plays Metallica By Four Cellos
# Black Album
